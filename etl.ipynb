# %%
# imports
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
# Pandas CSV
csv_file = "data/SO_pandas.csv"
so_pandas_df = pd.read_csv(csv_file)
so_pandas_df.head()
# Out:
#    Unnamed: 0  Post Link    Type  \
# 0           0   10348407  Answer
# 1           1   10483954  Answer
# 2           2   10499966  Answer
# 3           3   10312647  Answer
# 4           4   10374652  Answer
#
#                                                Title  \
# 0  Use wxpython DrawText function to add text in ...
# 1                        Selenium grid 2 over cygwin
# 2  Issue with concatenation with delimiter formul...
# 3  Concatenate or print list elements with a trai...
# 4              Python: Exploring data of GUI program
#
#                                             Markdown  \
# 0  When I run your code, I got an error as there ...
# 1  Through ssh, you only exchange with Windows st...
# 2  You are calling `SUBSTITUTE` on space characte...
# 3  If you are in Python 3, you could leverage the...
# 4  Let's wrap up this thread...\r\r\n\r\r\n`pywin...
#
#                                                 Tags              Created  \
# 0         <python><bitmap><wxpython><draw><drawtext>  2012-04-27 09:45:58
# 1                 <windows-7><cygwin><selenium-grid>  2012-05-07 14:34:44
# 2  <excel><excel-vba><excel-2007><excel-formula><...  2012-05-08 13:50:52
# 3                       <python><string><list><join>  2012-04-25 09:14:04
# 4                <python><user-interface><variables>  2012-04-29 18:12:49
#
#              Last Edit      Edited By  Score  Favorites    Views  Answers  \
# 0                  NaN            NaN      0        NaN   1312.0      NaN
# 1                  NaN            NaN      2        NaN    438.0      NaN
# 2                  NaN            NaN      4        NaN    734.0      NaN
# 3  2012-04-25 11:44:45  Boud (624829)      6        NaN  18242.0      NaN
# 4                  NaN            NaN      1        NaN    271.0      NaN
#
#    Accepted   CW Closed
# 0       NaN  NaN    NaN
# 1  Accepted  NaN    NaN
# 2       NaN  NaN    NaN
# 3       NaN  NaN    NaN
# 4  Accepted  NaN    NaN

# %%
# Python Answers CSV
csv_file ='data/Answers_small1.csv'
so_python_answers_df = pd.read_csv(csv_file, encoding='utf-8')
so_python_answers_df
# Out:
#           Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0        497         50.0  2008-08-02T16:56:53Z       469      4
# 1        518        153.0  2008-08-02T17:42:28Z       469      2
# 2        536        161.0  2008-08-02T18:49:07Z       502      9
# 3        538        156.0  2008-08-02T18:56:56Z       535     23
# 4        541        157.0  2008-08-02T19:06:40Z       535     20
# ...      ...          ...                   ...       ...    ...
# 2152  144212      15682.0  2008-09-27T18:42:39Z    144201     17
# 2153  144225      23033.0  2008-09-27T18:53:49Z    144218      0
# 2154  144231          NaN  2008-09-27T18:58:37Z    144218      2
# 2155  144253      11549.0  2008-09-27T19:11:46Z    144218      0
# 2156  144263      10661.0  2008-09-27T19:17:57Z    144218      0
#
#                                                    Body
# 0     <p>open up a terminal (Applications-&gt;Utilit...
# 1     <p>I haven't been able to find anything that d...
# 2     <p>You can use ImageMagick's convert utility f...
# 3     <p>One possibility is Hudson.  It's written in...
# 4     <p>We run <a href="http://buildbot.net/trac">B...
# ...                                                 ...
# 2152  <p><a href="http://www.sontek.net/python-with-...
# 2153  <p>Decimal defaults to 28 places of precision....
# 2154  <p>Decimals won't throw away decimal places li...
# 2155  <p>If I undertand Decimal correctly, the "prec...
# 2156  <p>What's wrong with floating point?  </p>\n\n...
#
# [2157 rows x 6 columns]

# %%
# Python Questions CSV
csv_file ='data/Questions_small.csv'
so_python_questions_df = pd.read_csv(csv_file, encoding='latin-1')
so_python_questions_df
# Out:
#           Id  OwnerUserId          CreationDate  Score  \
# 0        469        147.0  2008-08-02T15:11:16Z     21
# 1        502        147.0  2008-08-02T17:01:58Z     27
# 2        535        154.0  2008-08-02T18:43:54Z     40
# 3        594        116.0  2008-08-03T01:15:08Z     25
# 4        683        199.0  2008-08-03T13:19:16Z     28
# ...      ...          ...                   ...    ...
# 1625  352079      37575.0  2008-12-09T08:09:07Z      3
# 1626  352340    2220518.0  2008-12-09T10:34:14Z      1
# 1627  352478      18909.0  2008-12-09T11:42:47Z     25
# 1628  352537        115.0  2008-12-09T12:01:30Z     17
# 1629  352670      12030.0  2008-12-09T13:15:00Z     43
#
#                                                   Title  \
# 0     How can I find the full path to a font from it...
# 1               Get a preview JPEG of a PDF on Windows?
# 2     Continuous Integration System for a Python Cod...
# 3        cx_Oracle: How do I iterate over a result set?
# 4     Using 'in' to match an attribute of Python obj...
# ...                                                 ...
# 1625  How to adding middleware to Appengine's webapp...
# 1626                     Return file from python module
# 1627                                Capitalize a string
# 1628                Extending builtin classes in python
# 1629  Weighted random selection with and without rep...
#
#                                                    Body
# 0     <p>I am using the Photoshop's javascript API t...
# 1     <p>I have a cross-platform (Python) applicatio...
# 2     <p>I'm starting work on a hobby project with a...
# 3     <p>There are several ways to iterate over a re...
# 4     <p>I don't remember whether I was dreaming or ...
# ...                                                 ...
# 1625  <p>Im using the appengine webapp framework (<a...
# 1626  <p>Edit: How to return/serve a file from a pyt...
# 1627  <p>Does anyone know of a really simple way of ...
# 1628  <p>How can I extend a builtin class in python?...
# 1629  <p>Recently I needed to do weighted random sel...
#
# [1630 rows x 6 columns]

# %%
# Python Tags CSV
csv_file ='data/Tags.csv'
so_python_tags_df = pd.read_csv(csv_file, encoding='latin-1')
so_python_tags_df.head()
# Out:
#     Id        Tag
# 0  469     python
# 1  469        osx
# 2  469      fonts
# 3  469  photoshop
# 4  502     python

# %%
# Join dfs
a = so_python_questions_df.set_index("Id").join(so_python_answers_df.set_index("ParentId"), lsuffix="_question", rsuffix="_answer")
b = a.dropna()
b
# Out:
#         OwnerUserId_question CreationDate_question  Score_question  \
# 469                    147.0  2008-08-02T15:11:16Z              21
# 469                    147.0  2008-08-02T15:11:16Z              21
# 469                    147.0  2008-08-02T15:11:16Z              21
# 502                    147.0  2008-08-02T17:01:58Z              27
# 502                    147.0  2008-08-02T17:01:58Z              27
# ...                      ...                   ...             ...
# 143632               12344.0  2008-09-27T13:15:33Z               5
# 144201             1367022.0  2008-09-27T18:28:42Z              22
# 144218                2147.0  2008-09-27T18:47:54Z               4
# 144218                2147.0  2008-09-27T18:47:54Z               4
# 144218                2147.0  2008-09-27T18:47:54Z               4
#
#                                                     Title  \
# 469     How can I find the full path to a font from it...
# 469     How can I find the full path to a font from it...
# 469     How can I find the full path to a font from it...
# 502               Get a preview JPEG of a PDF on Windows?
# 502               Get a preview JPEG of a PDF on Windows?
# ...                                                   ...
# 143632  Crypto/X509 certificate parsing libraries for ...
# 144201  Has anyone found a good set of python plugins ...
# 144218          Significant figures in the decimal module
# 144218          Significant figures in the decimal module
# 144218          Significant figures in the decimal module
#
#                                             Body_question        Id  \
# 469     <p>I am using the Photoshop's javascript API t...     497.0
# 469     <p>I am using the Photoshop's javascript API t...     518.0
# 469     <p>I am using the Photoshop's javascript API t...    3040.0
# 502     <p>I have a cross-platform (Python) applicatio...     536.0
# 502     <p>I have a cross-platform (Python) applicatio...    7073.0
# ...                                                   ...       ...
# 143632  <p>Any recommended crypto libraries for Python...  144087.0
# 144201  <p>I'm looking for a suite of plugins that can...  144212.0
# 144218  <p>So I've decided to try to solve my physics ...  144225.0
# 144218  <p>So I've decided to try to solve my physics ...  144253.0
# 144218  <p>So I've decided to try to solve my physics ...  144263.0
#
#         OwnerUserId_answer   CreationDate_answer  Score_answer  \
# 469                   50.0  2008-08-02T16:56:53Z           4.0
# 469                  153.0  2008-08-02T17:42:28Z           2.0
# 469                  457.0  2008-08-06T03:01:23Z          12.0
# 502                  161.0  2008-08-02T18:49:07Z           9.0
# 502                  878.0  2008-08-10T07:10:19Z           2.0
# ...                    ...                   ...           ...
# 143632             22351.0  2008-09-27T17:28:36Z           3.0
# 144201             15682.0  2008-09-27T18:42:39Z          17.0
# 144218             23033.0  2008-09-27T18:53:49Z           0.0
# 144218             11549.0  2008-09-27T19:11:46Z           0.0
# 144218             10661.0  2008-09-27T19:17:57Z           0.0
#
#                                               Body_answer
# 469     <p>open up a terminal (Applications-&gt;Utilit...
# 469     <p>I haven't been able to find anything that d...
# 469     <p>Unfortunately the only API that isn't depre...
# 502     <p>You can use ImageMagick's convert utility f...
# 502     <p>Is the PC likely to have Acrobat installed?...
# ...                                                   ...
# 143632  <p>You might want to try <a href="http://www.k...
# 144201  <p><a href="http://www.sontek.net/python-with-...
# 144218  <p>Decimal defaults to 28 places of precision....
# 144218  <p>If I undertand Decimal correctly, the "prec...
# 144218  <p>What's wrong with floating point?  </p>\n\n...
#
# [2026 rows x 10 columns]

# %%
# Rename columns
dicti = {
    "OwnerUserId_question": "Questioner_Id",
    "CreationDate_question": "Question_Asked_Date",
    "Score_question": "Question_Score",
    "Title": "Question_Title",
    "Body_question": "Question_Text",
    "Id": "Id",
    "OwnerUserId_answer": "Answerer_ID",
    "CreationDate_answer": "Question_Answered_Date",
    "Score_answer": "Answer_Score",
    "Body_answer": "Answer_Text"
}

c = b.rename(columns=dicti)

c
# Out:
#         Questioner_Id   Question_Asked_Date  Question_Score  \
# 469             147.0  2008-08-02T15:11:16Z              21
# 469             147.0  2008-08-02T15:11:16Z              21
# 469             147.0  2008-08-02T15:11:16Z              21
# 502             147.0  2008-08-02T17:01:58Z              27
# 502             147.0  2008-08-02T17:01:58Z              27
# ...               ...                   ...             ...
# 143632        12344.0  2008-09-27T13:15:33Z               5
# 144201      1367022.0  2008-09-27T18:28:42Z              22
# 144218         2147.0  2008-09-27T18:47:54Z               4
# 144218         2147.0  2008-09-27T18:47:54Z               4
# 144218         2147.0  2008-09-27T18:47:54Z               4
#
#                                            Question_Title  \
# 469     How can I find the full path to a font from it...
# 469     How can I find the full path to a font from it...
# 469     How can I find the full path to a font from it...
# 502               Get a preview JPEG of a PDF on Windows?
# 502               Get a preview JPEG of a PDF on Windows?
# ...                                                   ...
# 143632  Crypto/X509 certificate parsing libraries for ...
# 144201  Has anyone found a good set of python plugins ...
# 144218          Significant figures in the decimal module
# 144218          Significant figures in the decimal module
# 144218          Significant figures in the decimal module
#
#                                             Question_Text        Id  \
# 469     <p>I am using the Photoshop's javascript API t...     497.0
# 469     <p>I am using the Photoshop's javascript API t...     518.0
# 469     <p>I am using the Photoshop's javascript API t...    3040.0
# 502     <p>I have a cross-platform (Python) applicatio...     536.0
# 502     <p>I have a cross-platform (Python) applicatio...    7073.0
# ...                                                   ...       ...
# 143632  <p>Any recommended crypto libraries for Python...  144087.0
# 144201  <p>I'm looking for a suite of plugins that can...  144212.0
# 144218  <p>So I've decided to try to solve my physics ...  144225.0
# 144218  <p>So I've decided to try to solve my physics ...  144253.0
# 144218  <p>So I've decided to try to solve my physics ...  144263.0
#
#         Answerer_ID Question_Answered_Date  Answer_Score  \
# 469            50.0   2008-08-02T16:56:53Z           4.0
# 469           153.0   2008-08-02T17:42:28Z           2.0
# 469           457.0   2008-08-06T03:01:23Z          12.0
# 502           161.0   2008-08-02T18:49:07Z           9.0
# 502           878.0   2008-08-10T07:10:19Z           2.0
# ...             ...                    ...           ...
# 143632      22351.0   2008-09-27T17:28:36Z           3.0
# 144201      15682.0   2008-09-27T18:42:39Z          17.0
# 144218      23033.0   2008-09-27T18:53:49Z           0.0
# 144218      11549.0   2008-09-27T19:11:46Z           0.0
# 144218      10661.0   2008-09-27T19:17:57Z           0.0
#
#                                               Answer_Text
# 469     <p>open up a terminal (Applications-&gt;Utilit...
# 469     <p>I haven't been able to find anything that d...
# 469     <p>Unfortunately the only API that isn't depre...
# 502     <p>You can use ImageMagick's convert utility f...
# 502     <p>Is the PC likely to have Acrobat installed?...
# ...                                                   ...
# 143632  <p>You might want to try <a href="http://www.k...
# 144201  <p><a href="http://www.sontek.net/python-with-...
# 144218  <p>Decimal defaults to 28 places of precision....
# 144218  <p>If I undertand Decimal correctly, the "prec...
# 144218  <p>What's wrong with floating point?  </p>\n\n...
#
# [2026 rows x 10 columns]

# %%
# Turn all floats to int
c["Questioner_Id"] = round(c["Questioner_Id"].astype(int),0)
c["Id"] = round(c["Id"].astype(int),0)
c["Answerer_ID"] = round(c["Answerer_ID"].astype(int),0)
c["Answer_Score"] = round(c["Answer_Score"].astype(int),0)

c.dtypes
# Out:
# Questioner_Id              int32
# Question_Asked_Date       object
# Question_Score             int64
# Question_Title            object
# Question_Text             object
# Id                         int32
# Answerer_ID                int32
# Question_Answered_Date    object
# Answer_Score               int32
# Answer_Text               object
# dtype: object

# %%
# Perform L
rds_connection_string = "postgres:postgres@localhost:5432/sodb"
engine = create_engine(f'postgresql://{rds_connection_string}')

engine.table_names()

c.to_sql(name='so_QA', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  database "sodb" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-9-fc0153e7e342> in <module>
#       3 engine = create_engine(f'postgresql://{rds_connection_string}')
#       4
# ----> 5 engine.table_names()
#       6
#       7 c.to_sql(name='so_QA', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2317         """
#    2318
# -> 2319         with self._optional_conn_ctx_manager(connection) as conn:
#    2320             return self.dialect.get_table_names(conn, schema)
#    2321
#
# ~\anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2087     def _optional_conn_ctx_manager(self, connection=None):
#    2088         if connection is None:
# -> 2089             with self._contextual_connect() as conn:
#    2090                 yield conn
#    2091         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2303         return self._connection_cls(
#    2304             self,
# -> 2305             self._wrap_pool_connect(self.pool.connect, None),
#    2306             close_with_result=close_with_result,
#    2307             **kwargs
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
# -> 2342                 Connection._handle_dbapi_exception_noconnection(
#    2343                     e, dialect, self
#    2344                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1583         elif should_wrap:
# -> 1584             util.raise_(
#    1585                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1586             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         dialect = self.dialect
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  database "sodb" does not exist
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
pd.read_sql_query('select * from so_QA', con=engine).head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  database "sodb" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-10-bd6ea6d3d468> in <module>
# ----> 1 pd.read_sql_query('select * from so_QA', con=engine).head()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     375     """
#     376     pandas_sql = pandasSQL_builder(con)
# --> 377     return pandas_sql.read_query(
#     378         sql,
#     379         index_col=index_col,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1293         args = _convert_params(sql, params)
#    1294
# -> 1295         result = self.execute(*args)
#    1296         columns = result.keys()
#    1297
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1159     def execute(self, *args, **kwargs):
#    1160         """Simple passthrough to SQLAlchemy connectable"""
# -> 1161         return self.connectable.execution_options(no_parameters=True).execute(
#    1162             *args, **kwargs
#    1163         )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2235         """
#    2236
# -> 2237         connection = self._contextual_connect(close_with_result=True)
#    2238         return connection.execute(statement, *multiparams, **params)
#    2239
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2303         return self._connection_cls(
#    2304             self,
# -> 2305             self._wrap_pool_connect(self.pool.connect, None),
#    2306             close_with_result=close_with_result,
#    2307             **kwargs
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
# -> 2342                 Connection._handle_dbapi_exception_noconnection(
#    2343                     e, dialect, self
#    2344                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1583         elif should_wrap:
# -> 1584             util.raise_(
#    1585                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1586             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         dialect = self.dialect
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  database "sodb" does not exist
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)
